# %% [markdown]
# # Data List Task Student Id Total marks and average

# %%
id = [1,2,3,4]
Eng = [70,80,90,60]
Math = [90,90,80,80]
Computer = [80,80,90,90]

for i in range(len(id)):
    total = Eng[i]+Math[i]+Computer[i]
    average = total /3
    print(f"Student Id : {id[i]}")
    print(f"Total Number is : {total}")
    print(f"Average Number is : {average}")
# Out:
# Student Id : 1
# Total Number is : 240
# Average Number is : 80.0
# Student Id : 2
# Total Number is : 250
# Average Number is : 83.33333333333333
# Student Id : 3
# Total Number is : 260
# Average Number is : 86.66666666666667
# Student Id : 4
# Total Number is : 230
# Average Number is : 76.66666666666667

# %%
# Data List  tuple concept

# %%
thistuple = ("apple", "banana", "cherry")
print(len(thistuple))
# Out:
# 3

# %%
tuple1 = ("apple", "banana", "cherry")
tuple2 = (1, 5, 7, 9, 3)
tuple3 = (True, False, False)
print(type(tuple1))
print(type(tuple2))
print(type(tuple3))
# Out:
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>

# %%
tuple1 = ("abc", 34, True, 40, "male")
print(type(tuple1))
tuple1.count(4)
result = tuple.index("male")
print(result)
# Out:
# <class 'tuple'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 4
#       2 print(type(tuple1))
#       3 tuple1.count(4)
# ----> 4 result = tuple.index("male")
#       5 print(result)
#
# TypeError: descriptor 'index' for 'tuple' objects doesn't apply to a 'str' object

# %%
text = ("abc", 34, True, 40, "male")
result = text.index("male")
print(result)
# Out:
# 4
