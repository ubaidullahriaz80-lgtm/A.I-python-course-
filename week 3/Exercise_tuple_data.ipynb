# %% [markdown]
# # Creating tuple Data

# %%
numbers = (1, 2, -5)
print(numbers)
# Out:
# (1, 2, -5)

# %% [markdown]
# # Tuple Cannot be Modified

# %%
cars = ('BMW', 'Tesla', 'Ford', 'Toyota')

# trying to modify a tuple
cars[0] = 'Nissan'  
       
print(cars)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 cars = ('BMW', 'Tesla', 'Ford', 'Toyota')
#       3 # trying to modify a tuple
# ----> 4 cars[0] = 'Nissan'    # error
#       6 print(cars)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # Python Tuple Length

# %%
cars = ('BMW', 'Tesla', 'Ford', 'Toyota')
print('Total Items:', len(cars))
# Out:
# Total Items: 4

# %% [markdown]
# # Iterate Through a Tuple

# %%
fruits = ('apple','banana','orange')

for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# orange

# %% [markdown]
# # Check if an Item Exists in the Tuple

# %%
colors = ('red', 'orange', 'blue')

print('yellow' in colors)    
print('red' in colors)
# Out:
# False
# True

# %% [markdown]
# # Change Tuple Items

# %%
fruits = ('apple', 'cherry', 'orange')

# trying to change the second item to 'banana'
fruits[1] = 'banana'

print(fruits) 

# Output: TypeError: 'tuple' object does not support item assignment
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       1 fruits = ('apple', 'cherry', 'orange')
#       3 # trying to change the second item to 'banana'
# ----> 4 fruits[1] = 'banana'
#       6 print(fruits)
#       8 # Output: TypeError: 'tuple' object does not support item assignment
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # Delete Tuples

# %%
animals = ('dog', 'cat', 'rat')

# deleting the tuple
del animals

# %% [markdown]
# # Create a Python Tuple With One Item

# %%
var = ('Hello')
print(var)  # string
# Out:
# Hello
